# %%
import numpy as np
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pylab as plt
from sklearn import datasets, ensemble, model_selection
from sklearn.ensemble import RandomForestClassifier

# %%
cancer = datasets.load_breast_cancer()
X_train, X_test, y_train, y_test = model_selection.train_test_split(cancer.data, cancer.target, random_state=0)

# %%
cls_t = tree.DecisionTreeClassifier()
cls_t.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
importances = cls_t.feature_importances_
indices = np.argsort(importances)
features = cancer.feature_names
plt.title('Feature Importances')
j = 11# top j importance
plt.barh(range(j), importances[indices][len(indices)-j:], color='g', align='center')
plt.yticks(range(j), [features[i] for i in indices[len(indices)-j:]])
plt.xlabel('Relative Importance')
plt.show()

# %%
# visualization
fig = plt.figure(figsize=(16, 8))
vis = tree.plot_tree(cls_t, feature_names = cancer.feature_names, class_names = ['Benign', 'Malignant'], max_depth=3, fontsize=9, proportion=True, filled=True, rounded=True)

# %%
from sklearn.ensemble import RandomForestClassifier
cls_rt = RandomForestClassifier()
cls_rt.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
importances = cls_rt.feature_importances_
indices = np.argsort(importances)
features = cancer.feature_names
print(importances)
plt.title('Feature Importances')
j = 11# top j importance
plt.barh(range(j), importances[indices][len(indices)-j:], color='g', align='center')
plt.yticks(range(j), [features[i] for i in indices[len(indices)-j:]])
plt.xlabel('Relative Importance')
plt.show()
# Out:
# [0.03272042 0.01571477 0.05910984 0.05605636 0.00664285 0.0066185
#  0.04030579 0.1022351  0.00522717 0.00199976 0.0105043  0.00429397
#  0.01424631 0.05200743 0.00389661 0.00642196 0.00407512 0.00904534
#  0.00498323 0.00604848 0.05174357 0.01798318 0.18264946 0.09817004
#  0.00917576 0.01481039 0.02883004 0.13431386 0.01297132 0.00719905]

# %%
estimator = cls_rt.estimators_[5]
# visualization
fig = plt.figure(figsize=(16, 8))
vis = tree.plot_tree(estimator, feature_names = cancer.feature_names, class_names = ['Benign', 'Malignant'], max_depth=3, fontsize=9, proportion=True, filled=True, rounded=True)
